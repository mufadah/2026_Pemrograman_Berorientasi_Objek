# %% [markdown]
# <a href="https://colab.research.google.com/github/mufadah/2026_Pemrograman_Berorientasi_Objek/blob/main/Jobsheet_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 01 -

# %% [markdown]
# #Praktikum 02 -

# %% [markdown]
# #Praktikum 03 -

# %% [markdown]
# #Praktikum 04 -

# %% [markdown]
# #Praktikum 05 -

# %% [markdown]
# #Praktikum 06 -

# %% [markdown]
# #Penugasan 01 -

# %% [markdown]
# #Penugasan 02 -

# %% [markdown]
# #Penugasan 03 -

# %% [markdown]
# #Penugasan 04 -
