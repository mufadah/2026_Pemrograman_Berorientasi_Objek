# %% [markdown]
# <a href="https://colab.research.google.com/github/mufadah/2026_Pemrograman_Berorientasi_Objek/blob/main/Jobsheet04/Jobsheet_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 01 - Inheritance Dasar

# %% [markdown]
# #Praktikum 02 - Menggunakan super() dalam Konstruktor

# %% [markdown]
# #Praktikum 03 - Method Overriding dan super()

# %% [markdown]
# #Praktikum 04 - Multi-level Inheritance (Pewarisan Bertingkat)

# %% [markdown]
# #Praktikum 05 - Hierarchical	Inheritance (Pewarisan Hierarkis)

# %% [markdown]
# #Praktikum 06 - Memeriksa Tipe Instance dengan isinstance()

# %% [markdown]
# #Penugasan 01 - Hierarki Kelas Mahasiswa
